# %%
from utils_prediction.database import (gbq_connect, gbq_query)
from utils_prediction.dataloader.mimic4 import dataloader
from utils_prediction.preprocessor import (fill_missing,discretizer,binary_discretizer,one_hot_encoder,prune_features)

from utils_prediction.nn.group_fairness import group_regularized_model
from utils_prediction.nn.robustness import group_robust_model

from sklearn.pipeline import Pipeline

import os
import pyarrow as pa
import pyarrow.parquet as pq

# %% [markdown]
# #### Get example features from GBQ and save to disk

# %%
## Establish connection with GBQ
c = gbq_connect(
    service_account_json_path = '/hpf/projects/lsung/creds/gbq/mimic.json', # change to your service account auth
    project_id = 'mimic-iv-ches'
    )

## Grab example data
df = gbq_query(c, """
    select * from `mimic-iv-ches.demo.mimic4_slice`
    """, verbose = False)

## Save to disk
path = 'data/analysis_id=demo'

if not os.path.exists(path): os.makedirs(path)

pq.write_table(
    pa.Table.from_pandas(df),
    f"{path}/features.parquet"
    )
# Out:
# Google Big Query Connection Established

# %% [markdown]
# #### Load data & split into train,val,test
# - retain group info

# %%
data = dataloader(
    analysis_id = 'demo',
    features_fpath = 'data'
    ).load_features()
data = data.split(retain_group_var=True)

# %%
len(data.X_train), len(data.X_val), len(data.X_test)
# Out:
# (1400, 300, 300)

# %% [markdown]
# #### Preprocessing pipeline

# %%
## Pipeline
pipe = Pipeline([
    ('fill missings',fill_missing(config={'count':0,'marital_status':'None'})),
    ('prune features',prune_features(special_cols={'count':0})),
    ('discretize counts', binary_discretizer(feature_tags_to_include= ['count'])),
    ('discretize measurements', discretizer(feature_tags_to_include = ['measurement'])),
    ('one hot encode', one_hot_encoder(feature_tags_to_exclude = ['count','group_var']))
    ])

# %% [markdown]
# #### Preprocess data

# %%
data.X_train = pipe.fit_transform(data.X_train)
data.X_val = pipe.transform(data.X_val)
data.X_test = pipe.transform(data.X_test)

# %% [markdown]
# #### Generate torch dataloaders
# - use retained group info to define attribtue

# %%
loaders = data.to_torch(
    group_var_name='group_var',
    balance_groups=False
)
# Out:
# ['2008 - 2010' '2011 - 2013' '2014 - 2016' '2017 - 2019']

# %% [markdown]
# #### Group Coral Model

# %%
model_class = group_regularized_model(model_type="group_coral")
m = model_class(**{
        "num_epochs":10,
        "num_hidden":2,
        "input_dim":next(iter(loaders['train']))['features'].shape[1],
        "drop_prob":0.5,
        "lambda_group_regularization":100,
        "group_regularization_mode":"group"
    }
)
#m.model.parameters
m.train(loaders)
# Out:
# cpu
# Epoch 0/9
# ----------
# /hpf/projects/lsung/envs/anaconda/mimic4/lib/python3.8/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0
# Phase: train:
#                  metric  performance
# 0                   auc     0.524782
# 1                 auprc     0.079076
# 2                 brier     0.192339
# 3              loss_bce     0.570713
# 4       specificity_0.5     0.749863
# 5         precision_0.5     0.078960
# 6            recall_0.5     0.280682
# 0                  loss     0.983325
# 1            supervised     0.570713
# 2  group_regularization     0.004126
# Phase: val:
#                  metric  performance
# 0                   auc     0.570798
# 1                 auprc     0.094337
# 2                 brier     0.080998
# 3              loss_bce     0.311385
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.442179
# 1            supervised     0.311385
# 2  group_regularization     0.001308
# Best model updated
# Epoch 1/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.544395
# 1                 auprc     0.079474
# 2                 brier     0.087785
# 3              loss_bce     0.323044
# 4       specificity_0.5     0.991637
# 5         precision_0.5     0.103604
# 6            recall_0.5     0.012735
# 0                  loss     0.606428
# 1            supervised     0.323044
# 2  group_regularization     0.002834
# Phase: val:
#                  metric  performance
# 0                   auc     0.594833
# 1                 auprc     0.098871
# 2                 brier     0.071269
# 3              loss_bce     0.276922
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.374023
# 1            supervised     0.276922
# 2  group_regularization     0.000971
# Best model updated
# Epoch 2/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.552920
# 1                 auprc     0.084804
# 2                 brier     0.078559
# 3              loss_bce     0.297429
# 4       specificity_0.5     0.998611
# 5         precision_0.5     0.153846
# 6            recall_0.5     0.003263
# 0                  loss     0.494211
# 1            supervised     0.297429
# 2  group_regularization     0.001968
# Phase: val:
#                  metric  performance
# 0                   auc     0.637672
# 1                 auprc     0.109305
# 2                 brier     0.069255
# 3              loss_bce     0.268162
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.343256
# 1            supervised     0.268162
# 2  group_regularization     0.000751
# Best model updated
# Epoch 3/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.558101
# 1                 auprc     0.091895
# 2                 brier     0.074681
# 3              loss_bce     0.286464
# 4       specificity_0.5     0.999663
# 5         precision_0.5     0.333333
# 6            recall_0.5     0.002166
# 0                  loss     0.426528
# 1            supervised     0.286464
# 2  group_regularization     0.001401
# Phase: val:
#                  metric  performance
# 0                   auc     0.673152
# 1                 auprc     0.123789
# 2                 brier     0.068239
# 3              loss_bce     0.263253
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.324140
# 1            supervised     0.263253
# 2  group_regularization     0.000609
# Best model updated
# Epoch 4/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.596068
# 1                 auprc     0.104016
# 2                 brier     0.072752
# 3              loss_bce     0.277630
# 4       specificity_0.5     1.000000
# 5         precision_0.5     1.000000
# 6            recall_0.5     0.000531
# 0                  loss     0.385752
# 1            supervised     0.277630
# 2  group_regularization     0.001081
# Phase: val:
#                  metric  performance
# 0                   auc     0.702256
# 1                 auprc     0.135104
# 2                 brier     0.067288
# 3              loss_bce     0.257846
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.309866
# 1            supervised     0.257846
# 2  group_regularization     0.000520
# Best model updated
# Epoch 5/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.607698
# 1                 auprc     0.106215
# 2                 brier     0.068875
# 3              loss_bce     0.265454
# 4       specificity_0.5     0.999916
# 5         precision_0.5     0.333333
# 6            recall_0.5     0.000554
# 0                  loss     0.350550
# 1            supervised     0.265454
# 2  group_regularization     0.000851
# Phase: val:
#                  metric  performance
# 0                   auc     0.729398
# 1                 auprc     0.152964
# 2                 brier     0.066591
# 3              loss_bce     0.253457
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.298801
# 1            supervised     0.253457
# 2  group_regularization     0.000453
# Best model updated
# Epoch 6/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.616485
# 1                 auprc     0.108164
# 2                 brier     0.068863
# 3              loss_bce     0.264167
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.336548
# 1            supervised     0.264167
# 2  group_regularization     0.000724
# Phase: val:
#                  metric  performance
# 0                   auc     0.743787
# 1                 auprc     0.158801
# 2                 brier     0.066247
# 3              loss_bce     0.251024
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.289683
# 1            supervised     0.251024
# 2  group_regularization     0.000387
# Best model updated
# Epoch 7/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.662656
# 1                 auprc     0.130957
# 2                 brier     0.068503
# 3              loss_bce     0.259050
# 4       specificity_0.5     0.999958
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.319891
# 1            supervised     0.259050
# 2  group_regularization     0.000608
# Phase: val:
#                  metric  performance
# 0                   auc     0.753924
# 1                 auprc     0.166263
# 2                 brier     0.065791
# 3              loss_bce     0.247740
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.281511
# 1            supervised     0.247740
# 2  group_regularization     0.000338
# Best model updated
# Epoch 8/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.688754
# 1                 auprc     0.153310
# 2                 brier     0.066194
# 3              loss_bce     0.250315
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.302360
# 1            supervised     0.250315
# 2  group_regularization     0.000520
# Phase: val:
#                  metric  performance
# 0                   auc     0.764388
# 1                 auprc     0.176494
# 2                 brier     0.065353
# 3              loss_bce     0.245046
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.274634
# 1            supervised     0.245046
# 2  group_regularization     0.000296
# Best model updated
# Epoch 9/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.700612
# 1                 auprc     0.162686
# 2                 brier     0.064734
# 3              loss_bce     0.244969
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.291731
# 1            supervised     0.244969
# 2  group_regularization     0.000468
# Phase: val:
#                  metric  performance
# 0                   auc     0.772400
# 1                 auprc     0.184830
# 2                 brier     0.065015
# 3              loss_bce     0.243355
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.268739
# 1            supervised     0.243355
# 2  group_regularization     0.000254
# Best model updated
# Best performance: 0.268739
# {'performance':      phase  epoch                metric  performance
#  0    train      0                   auc     0.524782
#  1    train      0                 auprc     0.079076
#  2    train      0                 brier     0.192339
#  3    train      0              loss_bce     0.570713
#  4    train      0       specificity_0.5     0.749863
#  ..     ...    ...                   ...          ...
#  195    val      9         precision_0.5     0.000000
#  196    val      9            recall_0.5     0.000000
#  197    val      9                  loss     0.268739
#  198    val      9            supervised     0.243355
#  199    val      9  group_regularization     0.000254
#
#  [200 rows x 4 columns]}

# %% [markdown]
# #### Group MMD Model

# %%
model_class = group_regularized_model(model_type="mean_prediction")
m = model_class(**{
        "num_epochs":10,
        "input_dim":next(iter(loaders['train']))['features'].shape[1],
        "lambda_group_regularization":1,
        "group_regularization_mode":"group",
    }
)
# Out:
# cpu

# %%
m.train(loaders)
# Out:
# Epoch 0/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.511476
# 1                 auprc     0.071333
# 2                 brier     0.145519
# 3              loss_bce     0.463508
# 4       specificity_0.5     0.865894
# 5         precision_0.5     0.062169
# 6            recall_0.5     0.113137
# 0                  loss     0.491889
# 1            supervised     0.463508
# 2  group_regularization     0.028382
# Phase: val:
#                  metric  performance
# 0                   auc     0.469261
# 1                 auprc     0.139968
# 2                 brier     0.075727
# 3              loss_bce     0.296358
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.311086
# 1            supervised     0.296358
# 2  group_regularization     0.014728
# Best model updated
# Epoch 1/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.555899
# 1                 auprc     0.079337
# 2                 brier     0.070626
# 3              loss_bce     0.273944
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.294358
# 1            supervised     0.273944
# 2  group_regularization     0.020414
# Phase: val:
#                  metric  performance
# 0                   auc     0.512917
# 1                 auprc     0.153245
# 2                 brier     0.068331
# 3              loss_bce     0.265432
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.294669
# 1            supervised     0.265432
# 2  group_regularization     0.029237
# Best model updated
# Epoch 2/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.628833
# 1                 auprc     0.093420
# 2                 brier     0.068147
# 3              loss_bce     0.261283
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.271654
# 1            supervised     0.261283
# 2  group_regularization     0.010371
# Phase: val:
#                  metric  performance
# 0                   auc     0.524526
# 1                 auprc     0.163930
# 2                 brier     0.067846
# 3              loss_bce     0.262621
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.301478
# 1            supervised     0.262621
# 2  group_regularization     0.038856
# Epoch 3/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.682896
# 1                 auprc     0.104452
# 2                 brier     0.065476
# 3              loss_bce     0.252160
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.259549
# 1            supervised     0.252160
# 2  group_regularization     0.007388
# Phase: val:
#                  metric  performance
# 0                   auc     0.553793
# 1                 auprc     0.174027
# 2                 brier     0.067759
# 3              loss_bce     0.261983
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.309418
# 1            supervised     0.261983
# 2  group_regularization     0.047435
# Epoch 4/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.746259
# 1                 auprc     0.138410
# 2                 brier     0.069873
# 3              loss_bce     0.263664
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.268724
# 1            supervised     0.263664
# 2  group_regularization     0.005059
# Phase: val:
#                  metric  performance
# 0                   auc     0.575049
# 1                 auprc     0.166160
# 2                 brier     0.067660
# 3              loss_bce     0.261248
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.313361
# 1            supervised     0.261248
# 2  group_regularization     0.052113
# Epoch 5/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.796094
# 1                 auprc     0.155068
# 2                 brier     0.063074
# 3              loss_bce     0.242775
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.248110
# 1            supervised     0.242775
# 2  group_regularization     0.005335
# Phase: val:
#                  metric  performance
# 0                   auc     0.580935
# 1                 auprc     0.186321
# 2                 brier     0.067737
# 3              loss_bce     0.261725
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.314652
# 1            supervised     0.261725
# 2  group_regularization     0.052927
# Epoch 6/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.813551
# 1                 auprc     0.168926
# 2                 brier     0.065318
# 3              loss_bce     0.248846
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.252910
# 1            supervised     0.248846
# 2  group_regularization     0.004065
# Phase: val:
#                  metric  performance
# 0                   auc     0.583715
# 1                 auprc     0.157514
# 2                 brier     0.067743
# 3              loss_bce     0.261712
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.319821
# 1            supervised     0.261712
# 2  group_regularization     0.058109
# Epoch 7/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.847924
# 1                 auprc     0.199485
# 2                 brier     0.064205
# 3              loss_bce     0.244627
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.248776
# 1            supervised     0.244627
# 2  group_regularization     0.004149
# Phase: val:
#                  metric  performance
# 0                   auc     0.600719
# 1                 auprc     0.179786
# 2                 brier     0.067639
# 3              loss_bce     0.260975
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.321643
# 1            supervised     0.260975
# 2  group_regularization     0.060668
# Epoch 8/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.865054
# 1                 auprc     0.213328
# 2                 brier     0.063774
# 3              loss_bce     0.242628
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.246672
# 1            supervised     0.242628
# 2  group_regularization     0.004044
# Phase: val:
#                  metric  performance
# 0                   auc     0.599084
# 1                 auprc     0.190147
# 2                 brier     0.067608
# 3              loss_bce     0.260701
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.328599
# 1            supervised     0.260701
# 2  group_regularization     0.067898
# Epoch 9/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.869013
# 1                 auprc     0.246200
# 2                 brier     0.067718
# 3              loss_bce     0.253169
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.257785
# 1            supervised     0.253169
# 2  group_regularization     0.004616
# Phase: val:
#                  metric  performance
# 0                   auc     0.590909
# 1                 auprc     0.173210
# 2                 brier     0.067615
# 3              loss_bce     0.260788
# 4       specificity_0.5     1.000000
# 5         precision_0.5     0.000000
# 6            recall_0.5     0.000000
# 0                  loss     0.331923
# 1            supervised     0.260788
# 2  group_regularization     0.071135
# Best performance: 0.294669
# {'performance':      phase  epoch                metric  performance
#  0    train      0                   auc     0.511476
#  1    train      0                 auprc     0.071333
#  2    train      0                 brier     0.145519
#  3    train      0              loss_bce     0.463508
#  4    train      0       specificity_0.5     0.865894
#  ..     ...    ...                   ...          ...
#  195    val      9         precision_0.5     0.000000
#  196    val      9            recall_0.5     0.000000
#  197    val      9                  loss     0.331923
#  198    val      9            supervised     0.260788
#  199    val      9  group_regularization     0.071135
#
#  [200 rows x 4 columns]}

# %% [markdown]
# #### Group Adversarial Model
# - using final layer activations as inputs to discriminator instead of logits of classifier output

# %% [markdown]
# #### Gradient reversal between features & discriminator
# - Objective: min L_cls + Lambd * L_adv, min L_adv

# %%
model_class = group_regularized_model(model_type="adversarial")
m = model_class(**{
        "num_epochs":10,
        "input_dim":next(iter(loaders['train']))['features'].shape[1],
        "output_dim_discriminator":4, #number of groups,
        "lambda_group_regularization":0.1,
        "use_layer_activations":True,
        "reverse_gradients":True,
    }
)
# Out:
# 4
# cpu

# %%
## train model
m.train(loaders,phases=['train','val'])
# Out:
# Epoch 0/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.472209
# 1              auprc     0.063448
# 2              brier     0.172484
# 3           loss_bce     0.521763
# 4    specificity_0.5     0.771636
# 5      precision_0.5     0.058976
# 6         recall_0.5     0.192221
# 0               loss     2.011852
# 1         supervised     0.521763
# 2      discriminator     1.490088
# 3  discriminator_alt     0.225503
# Phase: val:
#               metric  performance
# 0                auc     0.567037
# 1              auprc     0.121336
# 2              brier     0.072796
# 3           loss_bce     0.283589
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     1.898414
# 1         supervised     0.283589
# 2      discriminator     1.614825
# 3  discriminator_alt     0.199086
# Best model updated
# Epoch 1/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.546278
# 1              auprc     0.092492
# 2              brier     0.067522
# 3           loss_bce     0.262499
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     1.870719
# 1         supervised     0.262499
# 2      discriminator     1.608220
# 3  discriminator_alt     0.200767
# Phase: val:
#               metric  performance
# 0                auc     0.622956
# 1              auprc     0.162099
# 2              brier     0.066794
# 3           loss_bce     0.254632
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     2.090355
# 1         supervised     0.254633
# 2      discriminator     1.835723
# 3  discriminator_alt     0.159908
# Epoch 2/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.666484
# 1              auprc     0.169723
# 2              brier     0.064743
# 3           loss_bce     0.246837
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     2.110273
# 1         supervised     0.246837
# 2      discriminator     1.863436
# 3  discriminator_alt     0.156314
# Phase: val:
#               metric  performance
# 0                auc     0.683944
# 1              auprc     0.186301
# 2              brier     0.066144
# 3           loss_bce     0.249847
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     2.458401
# 1         supervised     0.249847
# 2      discriminator     2.208554
# 3  discriminator_alt     0.110675
# Epoch 3/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.745600
# 1              auprc     0.240586
# 2              brier     0.062895
# 3           loss_bce     0.236935
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     2.558861
# 1         supervised     0.236935
# 2      discriminator     2.321926
# 3  discriminator_alt     0.100157
# Phase: val:
#               metric  performance
# 0                auc     0.718280
# 1              auprc     0.207906
# 2              brier     0.065510
# 3           loss_bce     0.245669
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     3.178738
# 1         supervised     0.245669
# 2      discriminator     2.933068
# 3  discriminator_alt     0.054231
# Epoch 4/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.777519
# 1              auprc     0.282294
# 2              brier     0.060984
# 3           loss_bce     0.228329
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     3.621265
# 1         supervised     0.228329
# 2      discriminator     3.392936
# 3  discriminator_alt     0.037620
# Phase: val:
#               metric  performance
# 0                auc     0.736266
# 1              auprc     0.236205
# 2              brier     0.065124
# 3           loss_bce     0.242791
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     4.864569
# 1         supervised     0.242791
# 2      discriminator     4.621777
# 3  discriminator_alt     0.010239
# Epoch 5/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.784945
# 1              auprc     0.322161
# 2              brier     0.061482
# 3           loss_bce     0.227922
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     5.930160
# 1         supervised     0.227922
# 2      discriminator     5.702238
# 3  discriminator_alt     0.004595
# Phase: val:
#               metric  performance
# 0                auc     0.741334
# 1              auprc     0.235321
# 2              brier     0.064790
# 3           loss_bce     0.240818
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     7.715956
# 1         supervised     0.240818
# 2      discriminator     7.475138
# 3  discriminator_alt     0.000620
# Epoch 6/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.803014
# 1              auprc     0.333959
# 2              brier     0.060931
# 3           loss_bce     0.224182
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     8.842144
# 1         supervised     0.224182
# 2      discriminator     8.617962
# 3  discriminator_alt     0.000266
# Phase: val:
#               metric  performance
# 0                auc     0.751472
# 1              auprc     0.223165
# 2              brier     0.064705
# 3           loss_bce     0.239354
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss    10.670533
# 1         supervised     0.239354
# 2      discriminator    10.431179
# 3  discriminator_alt     0.000035
# Epoch 7/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.814549
# 1              auprc     0.349151
# 2              brier     0.061577
# 3           loss_bce     0.224688
# 4    specificity_0.5     1.000000
# 5      precision_0.5     1.000000
# 6         recall_0.5     0.000522
# 0               loss    11.675868
# 1         supervised     0.224688
# 2      discriminator    11.451180
# 3  discriminator_alt     0.000015
# Phase: val:
#               metric  performance
# 0                auc     0.760791
# 1              auprc     0.180268
# 2              brier     0.064588
# 3           loss_bce     0.237685
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss    13.557643
# 1         supervised     0.237685
# 2      discriminator    13.319958
# 3  discriminator_alt     0.000002
# Epoch 8/9
# ----------
# Phase: train:
#               metric   performance
# 0                auc  8.257895e-01
# 1              auprc  3.443072e-01
# 2              brier  5.989017e-02
# 3           loss_bce  2.185475e-01
# 4    specificity_0.5  1.000000e+00
# 5      precision_0.5  1.000000e+00
# 6         recall_0.5  7.466667e-03
# 0               loss  1.452350e+01
# 1         supervised  2.185475e-01
# 2      discriminator  1.430496e+01
# 3  discriminator_alt  9.715927e-07
# Phase: val:
#               metric   performance
# 0                auc  7.719097e-01
# 1              auprc  1.858616e-01
# 2              brier  6.450739e-02
# 3           loss_bce  2.360373e-01
# 4    specificity_0.5  1.000000e+00
# 5      precision_0.5  0.000000e+00
# 6         recall_0.5  0.000000e+00
# 0               loss  1.637273e+01
# 1         supervised  2.360374e-01
# 2      discriminator  1.613670e+01
# 3  discriminator_alt  1.452502e-07
# Epoch 9/9
# ----------
# Phase: train:
#               metric   performance
# 0                auc  8.260140e-01
# 1              auprc  3.636030e-01
# 2              brier  5.774964e-02
# 3           loss_bce  2.119409e-01
# 4    specificity_0.5  1.000000e+00
# 5      precision_0.5  1.000000e+00
# 6         recall_0.5  1.962923e-02
# 0               loss  1.724463e+01
# 1         supervised  2.119409e-01
# 2      discriminator  1.703269e+01
# 3  discriminator_alt  6.720516e-08
# Phase: val:
#               metric   performance
# 0                auc  7.694572e-01
# 1              auprc  1.854034e-01
# 2              brier  6.435714e-02
# 3           loss_bce  2.350570e-01
# 4    specificity_0.5  1.000000e+00
# 5      precision_0.5  0.000000e+00
# 6         recall_0.5  0.000000e+00
# 0               loss  1.912928e+01
# 1         supervised  2.350570e-01
# 2      discriminator  1.889422e+01
# 3  discriminator_alt  1.058300e-08
# Best performance: 1.898414
# {'performance':      phase  epoch             metric   performance
#  0    train      0                auc  4.722095e-01
#  1    train      0              auprc  6.344767e-02
#  2    train      0              brier  1.724837e-01
#  3    train      0           loss_bce  5.217633e-01
#  4    train      0    specificity_0.5  7.716360e-01
#  ..     ...    ...                ...           ...
#  215    val      9         recall_0.5  0.000000e+00
#  216    val      9               loss  1.912928e+01
#  217    val      9         supervised  2.350570e-01
#  218    val      9      discriminator  1.889422e+01
#  219    val      9  discriminator_alt  1.058300e-08
#
#  [220 rows x 4 columns]}

# %% [markdown]
# ##### Shuffle Group Labels
# - Objective: min L_cls + Lambd * L_adv, min L_adv

# %%
model_class = group_regularized_model(model_type="adversarial")
m = model_class(**{
        "num_epochs":10,
        "input_dim":next(iter(loaders['train']))['features'].shape[1],
        "output_dim_discriminator":4, #number of groups,
        "lambda_group_regularization":0.1,
        "use_layer_activations":True,
        "shuffle_group_labels":True,
    }
)
#m.model.parameters
# Out:
# 4
# cpu

# %%
## train model
m.train(loaders,phases=['train','val'])
# Out:
# Epoch 0/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.511055
# 1              auprc     0.077876
# 2              brier     0.166854
# 3           loss_bce     0.509109
# 4    specificity_0.5     0.791705
# 5      precision_0.5     0.074290
# 6         recall_0.5     0.200508
# 0               loss     0.653808
# 1         supervised     0.509109
# 2      discriminator     1.446991
# 3  discriminator_alt     0.235382
# Phase: val:
#               metric  performance
# 0                auc     0.658927
# 1              auprc     0.171869
# 2              brier     0.071829
# 3           loss_bce     0.280031
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     0.422253
# 1         supervised     0.280031
# 2      discriminator     1.422219
# 3  discriminator_alt     0.241444
# Best model updated
# Epoch 1/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.614473
# 1              auprc     0.103982
# 2              brier     0.070622
# 3           loss_bce     0.269529
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     0.411205
# 1         supervised     0.269529
# 2      discriminator     1.416757
# 3  discriminator_alt     0.242536
# Phase: val:
#               metric  performance
# 0                auc     0.703401
# 1              auprc     0.157819
# 2              brier     0.066209
# 3           loss_bce     0.251046
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     0.393326
# 1         supervised     0.251046
# 2      discriminator     1.422799
# 3  discriminator_alt     0.241058
# Best model updated
# Epoch 2/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.710668
# 1              auprc     0.159499
# 2              brier     0.063431
# 3           loss_bce     0.241600
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     0.382069
# 1         supervised     0.241600
# 2      discriminator     1.404683
# 3  discriminator_alt     0.245481
# Phase: val:
#               metric  performance
# 0                auc     0.734794
# 1              auprc     0.168373
# 2              brier     0.065744
# 3           loss_bce     0.246770
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     0.388832
# 1         supervised     0.246770
# 2      discriminator     1.420612
# 3  discriminator_alt     0.241585
# Best model updated
# Epoch 3/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.766306
# 1              auprc     0.264122
# 2              brier     0.064020
# 3           loss_bce     0.238867
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     0.378618
# 1         supervised     0.238867
# 2      discriminator     1.397513
# 3  discriminator_alt     0.247233
# Phase: val:
#               metric  performance
# 0                auc     0.757031
# 1              auprc     0.175501
# 2              brier     0.065354
# 3           loss_bce     0.243593
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     0.384366
# 1         supervised     0.243593
# 2      discriminator     1.407725
# 3  discriminator_alt     0.244775
# Best model updated
# Epoch 4/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.804569
# 1              auprc     0.319508
# 2              brier     0.060276
# 3           loss_bce     0.224080
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     0.363696
# 1         supervised     0.224080
# 2      discriminator     1.396162
# 3  discriminator_alt     0.247564
# Phase: val:
#               metric  performance
# 0                auc     0.764225
# 1              auprc     0.178769
# 2              brier     0.065115
# 3           loss_bce     0.240926
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     0.381210
# 1         supervised     0.240926
# 2      discriminator     1.402839
# 3  discriminator_alt     0.245916
# Best model updated
# Epoch 5/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.799127
# 1              auprc     0.319489
# 2              brier     0.060381
# 3           loss_bce     0.223714
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     0.363071
# 1         supervised     0.223714
# 2      discriminator     1.393568
# 3  discriminator_alt     0.248205
# Phase: val:
#               metric  performance
# 0                auc     0.773381
# 1              auprc     0.184884
# 2              brier     0.064849
# 3           loss_bce     0.238451
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     0.380389
# 1         supervised     0.238451
# 2      discriminator     1.419381
# 3  discriminator_alt     0.241868
# Best model updated
# Epoch 6/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.826698
# 1              auprc     0.374369
# 2              brier     0.060488
# 3           loss_bce     0.221092
# 4    specificity_0.5     1.000000
# 5      precision_0.5     1.000000
# 6         recall_0.5     0.002090
# 0               loss     0.360000
# 1         supervised     0.221092
# 2      discriminator     1.389083
# 3  discriminator_alt     0.249319
# Phase: val:
#               metric  performance
# 0                auc     0.778613
# 1              auprc     0.185247
# 2              brier     0.064644
# 3           loss_bce     0.236523
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     0.376522
# 1         supervised     0.236523
# 2      discriminator     1.399988
# 3  discriminator_alt     0.246615
# Best model updated
# Epoch 7/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.838167
# 1              auprc     0.389940
# 2              brier     0.055887
# 3           loss_bce     0.205700
# 4    specificity_0.5     1.000000
# 5      precision_0.5     1.000000
# 6         recall_0.5     0.016040
# 0               loss     0.344656
# 1         supervised     0.205700
# 2      discriminator     1.389564
# 3  discriminator_alt     0.249202
# Phase: val:
#               metric  performance
# 0                auc     0.779758
# 1              auprc     0.184137
# 2              brier     0.064770
# 3           loss_bce     0.235527
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     0.376687
# 1         supervised     0.235527
# 2      discriminator     1.411597
# 3  discriminator_alt     0.243754
# Epoch 8/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.840363
# 1              auprc     0.386049
# 2              brier     0.054718
# 3           loss_bce     0.201501
# 4    specificity_0.5     1.000000
# 5      precision_0.5     1.000000
# 6         recall_0.5     0.023073
# 0               loss     0.340251
# 1         supervised     0.201501
# 2      discriminator     1.387500
# 3  discriminator_alt     0.249714
# Phase: val:
#               metric  performance
# 0                auc     0.782047
# 1              auprc     0.186386
# 2              brier     0.064701
# 3           loss_bce     0.234212
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     0.375692
# 1         supervised     0.234212
# 2      discriminator     1.414799
# 3  discriminator_alt     0.242982
# Best model updated
# Epoch 9/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.846096
# 1              auprc     0.394580
# 2              brier     0.054917
# 3           loss_bce     0.201074
# 4    specificity_0.5     1.000000
# 5      precision_0.5     1.000000
# 6         recall_0.5     0.053414
# 0               loss     0.339811
# 1         supervised     0.201074
# 2      discriminator     1.387372
# 3  discriminator_alt     0.249744
# Phase: val:
#               metric  performance
# 0                auc     0.783028
# 1              auprc     0.183485
# 2              brier     0.064797
# 3           loss_bce     0.233848
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     0.373863
# 1         supervised     0.233848
# 2      discriminator     1.400150
# 3  discriminator_alt     0.246563
# Best model updated
# Best performance: 0.373863
# {'performance':      phase  epoch             metric  performance
#  0    train      0                auc     0.511055
#  1    train      0              auprc     0.077876
#  2    train      0              brier     0.166854
#  3    train      0           loss_bce     0.509109
#  4    train      0    specificity_0.5     0.791705
#  ..     ...    ...                ...          ...
#  215    val      9         recall_0.5     0.000000
#  216    val      9               loss     0.373863
#  217    val      9         supervised     0.233848
#  218    val      9      discriminator     1.400150
#  219    val      9  discriminator_alt     0.246563
#
#  [220 rows x 4 columns]}

# %% [markdown]
# ##### Only changing the objective
# Objective: min L_cls - Lambd * L_adv, min L_adv

# %%
model_class = group_regularized_model(model_type="adversarial")
m = model_class(**{
        "num_epochs":10,
        "input_dim":next(iter(loaders['train']))['features'].shape[1],
        "output_dim_discriminator":4, #number of groups,
        "lambda_group_regularization":0.1,
        "use_layer_activations":True
    }
)
#m.model.parameters
# Out:
# 4
# cpu

# %%
m.train(loaders,phases=['train','val'])
# Out:
# Epoch 0/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.480099
# 1              auprc     0.069826
# 2              brier     0.187417
# 3           loss_bce     0.556066
# 4    specificity_0.5     0.746808
# 5      precision_0.5     0.065630
# 6         recall_0.5     0.225548
# 0               loss     0.395368
# 1         supervised     0.556066
# 2      discriminator     1.606978
# 3  discriminator_alt     0.201162
# Phase: val:
#               metric  performance
# 0                auc     0.438031
# 1              auprc     0.066942
# 2              brier     0.080499
# 3           loss_bce     0.310721
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     0.133595
# 1         supervised     0.310721
# 2      discriminator     1.771265
# 3  discriminator_alt     0.170256
# Best model updated
# Epoch 1/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.542796
# 1              auprc     0.086648
# 2              brier     0.068900
# 3           loss_bce     0.268879
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss     0.042675
# 1         supervised     0.268879
# 2      discriminator     2.262045
# 3  discriminator_alt     0.110398
# Phase: val:
#               metric  performance
# 0                auc     0.520929
# 1              auprc     0.083692
# 2              brier     0.068606
# 3           loss_bce     0.264727
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss    -0.028228
# 1         supervised     0.264727
# 2      discriminator     2.929552
# 3  discriminator_alt     0.053551
# Best model updated
# Epoch 2/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.632633
# 1              auprc     0.134830
# 2              brier     0.064913
# 3           loss_bce     0.249461
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss    -0.137198
# 1         supervised     0.249461
# 2      discriminator     3.866587
# 3  discriminator_alt     0.024330
# Phase: val:
#               metric  performance
# 0                auc     0.640124
# 1              auprc     0.123431
# 2              brier     0.067333
# 3           loss_bce     0.256309
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss    -0.223751
# 1         supervised     0.256309
# 2      discriminator     4.800604
# 3  discriminator_alt     0.008279
# Best model updated
# Epoch 3/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.692926
# 1              auprc     0.176655
# 2              brier     0.065640
# 3           loss_bce     0.248078
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss    -0.331088
# 1         supervised     0.248078
# 2      discriminator     5.791663
# 3  discriminator_alt     0.003612
# Phase: val:
#               metric  performance
# 0                auc     0.687704
# 1              auprc     0.137670
# 2              brier     0.066667
# 3           loss_bce     0.251922
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss    -0.419117
# 1         supervised     0.251922
# 2      discriminator     6.710389
# 3  discriminator_alt     0.001236
# Best model updated
# Epoch 4/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.758418
# 1              auprc     0.251703
# 2              brier     0.064352
# 3           loss_bce     0.240248
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss    -0.525337
# 1         supervised     0.240248
# 2      discriminator     7.655845
# 3  discriminator_alt     0.000569
# Phase: val:
#               metric  performance
# 0                auc     0.718607
# 1              auprc     0.151763
# 2              brier     0.066103
# 3           loss_bce     0.247801
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss    -0.614571
# 1         supervised     0.247801
# 2      discriminator     8.623723
# 3  discriminator_alt     0.000184
# Best model updated
# Epoch 5/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.793560
# 1              auprc     0.304144
# 2              brier     0.061766
# 3           loss_bce     0.229223
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss    -0.735607
# 1         supervised     0.229223
# 2      discriminator     9.648305
# 3  discriminator_alt     0.000080
# Phase: val:
#               metric  performance
# 0                auc     0.750000
# 1              auprc     0.156309
# 2              brier     0.065633
# 3           loss_bce     0.243818
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss    -0.813774
# 1         supervised     0.243819
# 2      discriminator    10.575928
# 3  discriminator_alt     0.000027
# Best model updated
# Epoch 6/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.800991
# 1              auprc     0.323740
# 2              brier     0.059137
# 3           loss_bce     0.220551
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss    -0.940046
# 1         supervised     0.220551
# 2      discriminator    11.605963
# 3  discriminator_alt     0.000012
# Phase: val:
#               metric  performance
# 0                auc     0.760137
# 1              auprc     0.165735
# 2              brier     0.065593
# 3           loss_bce     0.242488
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss    -1.012117
# 1         supervised     0.242488
# 2      discriminator    12.546048
# 3  discriminator_alt     0.000004
# Best model updated
# Epoch 7/9
# ----------
# Phase: train:
#               metric  performance
# 0                auc     0.819838
# 1              auprc     0.340901
# 2              brier     0.059611
# 3           loss_bce     0.219633
# 4    specificity_0.5     1.000000
# 5      precision_0.5     0.000000
# 6         recall_0.5     0.000000
# 0               loss    -1.141476
# 1         supervised     0.219633
# 2      discriminator    13.611097
# 3  discriminator_alt     0.000002
# Phase: val:
#               metric   performance
# 0                auc  7.645520e-01
# 1              auprc  1.667955e-01
# 2              brier  6.533492e-02
# 3           loss_bce  2.408676e-01
# 4    specificity_0.5  1.000000e+00
# 5      precision_0.5  0.000000e+00
# 6         recall_0.5  0.000000e+00
# 0               loss -1.213887e+00
# 1         supervised  2.408676e-01
# 2      discriminator  1.454755e+01
# 3  discriminator_alt  5.211714e-07
# Best model updated
# Epoch 8/9
# ----------
# Phase: train:
#               metric   performance
# 0                auc  8.199298e-01
# 1              auprc  3.302656e-01
# 2              brier  5.797552e-02
# 3           loss_bce  2.143651e-01
# 4    specificity_0.5  1.000000e+00
# 5      precision_0.5  0.000000e+00
# 6         recall_0.5  0.000000e+00
# 0               loss -1.357423e+00
# 1         supervised  2.143651e-01
# 2      discriminator  1.571788e+01
# 3  discriminator_alt  2.079161e-07
# Phase: val:
#               metric   performance
# 0                auc  7.632440e-01
# 1              auprc  1.682352e-01
# 2              brier  6.526196e-02
# 3           loss_bce  2.396807e-01
# 4    specificity_0.5  1.000000e+00
# 5      precision_0.5  0.000000e+00
# 6         recall_0.5  0.000000e+00
# 0               loss -1.418992e+00
# 1         supervised  2.396807e-01
# 2      discriminator  1.658673e+01
# 3  discriminator_alt  6.976379e-08
# Best model updated
# Epoch 9/9
# ----------
# Phase: train:
#               metric   performance
# 0                auc  8.299747e-01
# 1              auprc  3.728193e-01
# 2              brier  5.909042e-02
# 3           loss_bce  2.164743e-01
# 4    specificity_0.5  1.000000e+00
# 5      precision_0.5  1.000000e+00
# 6         recall_0.5  1.321353e-02
# 0               loss -1.562447e+00
# 1         supervised  2.164743e-01
# 2      discriminator  1.778921e+01
# 3  discriminator_alt  2.779778e-08
# Phase: val:
#               metric   performance
# 0                auc  7.624264e-01
# 1              auprc  1.686213e-01
# 2              brier  6.527650e-02
# 3           loss_bce  2.394783e-01
# 4    specificity_0.5  1.000000e+00
# 5      precision_0.5  0.000000e+00
# 6         recall_0.5  0.000000e+00
# 0               loss -1.637712e+00
# 1         supervised  2.394783e-01
# 2      discriminator  1.877190e+01
# 3  discriminator_alt  8.186854e-09
# Best model updated
# Best performance: -1.637712
# {'performance':      phase  epoch             metric   performance
#  0    train      0                auc  4.800993e-01
#  1    train      0              auprc  6.982569e-02
#  2    train      0              brier  1.874172e-01
#  3    train      0           loss_bce  5.560660e-01
#  4    train      0    specificity_0.5  7.468077e-01
#  ..     ...    ...                ...           ...
#  215    val      9         recall_0.5  0.000000e+00
#  216    val      9               loss -1.637712e+00
#  217    val      9         supervised  2.394783e-01
#  218    val      9      discriminator  1.877190e+01
#  219    val      9  discriminator_alt  8.186854e-09
#
#  [220 rows x 4 columns]}

# %% [markdown]
# #### Group IRM Model

# %%
model_class = group_regularized_model(model_type="group_irm")
m = model_class(**{
        "num_epochs":10,
        "input_dim":next(iter(loaders['train']))['features'].shape[1],
        "lambda_group_regularization":100
    }
)
#m.model.parameters
# Out:
# cpu

# %%
## train model
m.train(loaders,phases=['train','val'])
# Out:
# Epoch 0/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.426774
# 1                 auprc     0.062304
# 2                 brier     0.262056
# 3              loss_bce     0.718229
# 4       specificity_0.5     0.471649
# 5         precision_0.5     0.058461
# 6            recall_0.5     0.405744
# 0                  loss     4.959316
# 1            supervised     0.718229
# 2  group_regularization     0.042411
# Phase: val:
#                  metric  performance
# 0                   auc     0.471387
# 1                 auprc     0.073846
# 2                 brier     0.241855
# 3              loss_bce     0.676356
# 4       specificity_0.5     0.557554
# 5         precision_0.5     0.082090
# 6            recall_0.5     0.500000
# 0                  loss     0.790089
# 1            supervised     0.676356
# 2  group_regularization     0.001137
# Best model updated
# Epoch 1/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.420637
# 1                 auprc     0.058780
# 2                 brier     0.243912
# 3              loss_bce     0.680554
# 4       specificity_0.5     0.546745
# 5         precision_0.5     0.051239
# 6            recall_0.5     0.311528
# 0                  loss     0.818877
# 1            supervised     0.680554
# 2  group_regularization     0.001383
# Phase: val:
#                  metric  performance
# 0                   auc     0.470896
# 1                 auprc     0.074021
# 2                 brier     0.242699
# 3              loss_bce     0.678092
# 4       specificity_0.5     0.550360
# 5         precision_0.5     0.080882
# 6            recall_0.5     0.500000
# 0                  loss     0.786226
# 1            supervised     0.678092
# 2  group_regularization     0.001081
# Best model updated
# Epoch 2/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.406486
# 1                 auprc     0.055365
# 2                 brier     0.244281
# 3              loss_bce     0.681336
# 4       specificity_0.5     0.547201
# 5         precision_0.5     0.047901
# 6            recall_0.5     0.299779
# 0                  loss     0.805684
# 1            supervised     0.681336
# 2  group_regularization     0.001243
# Phase: val:
#                  metric  performance
# 0                   auc     0.471060
# 1                 auprc     0.073678
# 2                 brier     0.242457
# 3              loss_bce     0.677619
# 4       specificity_0.5     0.561151
# 5         precision_0.5     0.075758
# 6            recall_0.5     0.454545
# 0                  loss     0.782221
# 1            supervised     0.677619
# 2  group_regularization     0.001046
# Best model updated
# Epoch 3/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.406625
# 1                 auprc     0.057460
# 2                 brier     0.244478
# 3              loss_bce     0.681732
# 4       specificity_0.5     0.546749
# 5         precision_0.5     0.048621
# 6            recall_0.5     0.296336
# 0                  loss     0.805016
# 1            supervised     0.681732
# 2  group_regularization     0.001233
# Phase: val:
#                  metric  performance
# 0                   auc     0.471550
# 1                 auprc     0.073401
# 2                 brier     0.241070
# 3              loss_bce     0.674820
# 4       specificity_0.5     0.568345
# 5         precision_0.5     0.076923
# 6            recall_0.5     0.454545
# 0                  loss     0.785157
# 1            supervised     0.674820
# 2  group_regularization     0.001103
# Epoch 4/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.417250
# 1                 auprc     0.058288
# 2                 brier     0.244779
# 3              loss_bce     0.682403
# 4       specificity_0.5     0.552260
# 5         precision_0.5     0.051689
# 6            recall_0.5     0.316249
# 0                  loss     0.788656
# 1            supervised     0.682403
# 2  group_regularization     0.001063
# Phase: val:
#                  metric  performance
# 0                   auc     0.472041
# 1                 auprc     0.073281
# 2                 brier     0.240472
# 3              loss_bce     0.673626
# 4       specificity_0.5     0.568345
# 5         precision_0.5     0.076923
# 6            recall_0.5     0.454545
# 0                  loss     0.789084
# 1            supervised     0.673626
# 2  group_regularization     0.001155
# Epoch 5/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.418469
# 1                 auprc     0.059413
# 2                 brier     0.244744
# 3              loss_bce     0.682290
# 4       specificity_0.5     0.552472
# 5         precision_0.5     0.052255
# 6            recall_0.5     0.309197
# 0                  loss     0.796349
# 1            supervised     0.682290
# 2  group_regularization     0.001141
# Phase: val:
#                  metric  performance
# 0                   auc     0.470896
# 1                 auprc     0.072957
# 2                 brier     0.243168
# 3              loss_bce     0.679135
# 4       specificity_0.5     0.550360
# 5         precision_0.5     0.074074
# 6            recall_0.5     0.454545
# 0                  loss     0.769619
# 1            supervised     0.679135
# 2  group_regularization     0.000905
# Best model updated
# Epoch 6/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.416078
# 1                 auprc     0.060032
# 2                 brier     0.245269
# 3              loss_bce     0.683402
# 4       specificity_0.5     0.552970
# 5         precision_0.5     0.054817
# 6            recall_0.5     0.320292
# 0                  loss     0.790476
# 1            supervised     0.683402
# 2  group_regularization     0.001071
# Phase: val:
#                  metric  performance
# 0                   auc     0.471223
# 1                 auprc     0.072541
# 2                 brier     0.244006
# 3              loss_bce     0.680861
# 4       specificity_0.5     0.532374
# 5         precision_0.5     0.071429
# 6            recall_0.5     0.454545
# 0                  loss     0.762476
# 1            supervised     0.680862
# 2  group_regularization     0.000816
# Best model updated
# Epoch 7/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.431193
# 1                 auprc     0.059071
# 2                 brier     0.245448
# 3              loss_bce     0.683767
# 4       specificity_0.5     0.554803
# 5         precision_0.5     0.060926
# 6            recall_0.5     0.378512
# 0                  loss     0.775720
# 1            supervised     0.683767
# 2  group_regularization     0.000920
# Phase: val:
#                  metric  performance
# 0                   auc     0.469097
# 1                 auprc     0.071818
# 2                 brier     0.245029
# 3              loss_bce     0.682952
# 4       specificity_0.5     0.528777
# 5         precision_0.5     0.070922
# 6            recall_0.5     0.454545
# 0                  loss     0.758429
# 1            supervised     0.682952
# 2  group_regularization     0.000755
# Best model updated
# Epoch 8/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.417377
# 1                 auprc     0.060247
# 2                 brier     0.245558
# 3              loss_bce     0.684002
# 4       specificity_0.5     0.557683
# 5         precision_0.5     0.060647
# 6            recall_0.5     0.357633
# 0                  loss     0.768061
# 1            supervised     0.684002
# 2  group_regularization     0.000841
# Phase: val:
#                  metric  performance
# 0                   auc     0.467626
# 1                 auprc     0.071624
# 2                 brier     0.244733
# 3              loss_bce     0.682362
# 4       specificity_0.5     0.528777
# 5         precision_0.5     0.070922
# 6            recall_0.5     0.454545
# 0                  loss     0.753961
# 1            supervised     0.682362
# 2  group_regularization     0.000716
# Best model updated
# Epoch 9/9
# ----------
# Phase: train:
#                  metric  performance
# 0                   auc     0.436127
# 1                 auprc     0.059075
# 2                 brier     0.245917
# 3              loss_bce     0.684745
# 4       specificity_0.5     0.553711
# 5         precision_0.5     0.062588
# 6            recall_0.5     0.392580
# 0                  loss     0.765703
# 1            supervised     0.684745
# 2  group_regularization     0.000810
# Phase: val:
#                  metric  performance
# 0                   auc     0.470405
# 1                 auprc     0.071915
# 2                 brier     0.244429
# 3              loss_bce     0.681769
# 4       specificity_0.5     0.546763
# 5         precision_0.5     0.073529
# 6            recall_0.5     0.454545
# 0                  loss     0.749880
# 1            supervised     0.681769
# 2  group_regularization     0.000681
# Best model updated
# Best performance: 0.749880
# {'performance':      phase  epoch                metric  performance
#  0    train      0                   auc     0.426774
#  1    train      0                 auprc     0.062304
#  2    train      0                 brier     0.262056
#  3    train      0              loss_bce     0.718229
#  4    train      0       specificity_0.5     0.471649
#  ..     ...    ...                   ...          ...
#  195    val      9         precision_0.5     0.073529
#  196    val      9            recall_0.5     0.454545
#  197    val      9                  loss     0.749880
#  198    val      9            supervised     0.681769
#  199    val      9  group_regularization     0.000681
#
#  [200 rows x 4 columns]}

# %% [markdown]
# #### Group DRO

# %%
model_class = group_robust_model(model_type="loss")
m = model_class(**{
        "num_epochs":10,
        "input_dim":next(iter(loaders['train']))['features'].shape[1],
        "num_groups":4,
        "lr_lambda":1e-1
    }
)
# Out:
# cpu

# %%
## train model
m.train(loaders,phases=['train','val'])
# Out:
# Epoch 0/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.518929
# 1            auprc     0.070546
# 2            brier     0.156061
# 3         loss_bce     0.483661
# 4  specificity_0.5     0.817290
# 5    precision_0.5     0.068833
# 6       recall_0.5     0.183059
# 0             loss     0.484054
# Phase: val:
#             metric  performance
# 0              auc     0.574722
# 1            auprc     0.105182
# 2            brier     0.072923
# 3         loss_bce     0.283061
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.288889
# Best model updated
# Epoch 1/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.627157
# 1            auprc     0.107032
# 2            brier     0.068522
# 3         loss_bce     0.262198
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.270888
# Phase: val:
#             metric  performance
# 0              auc     0.637508
# 1            auprc     0.136032
# 2            brier     0.066928
# 3         loss_bce     0.254711
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.280926
# Best model updated
# Epoch 2/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.742503
# 1            auprc     0.227949
# 2            brier     0.065452
# 3         loss_bce     0.245424
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.263258
# Phase: val:
#             metric  performance
# 0              auc     0.699150
# 1            auprc     0.157030
# 2            brier     0.066053
# 3         loss_bce     0.248376
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.290299
# Epoch 3/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.792947
# 1            auprc     0.292806
# 2            brier     0.060950
# 3         loss_bce     0.228308
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.247686
# Phase: val:
#             metric  performance
# 0              auc     0.747384
# 1            auprc     0.161832
# 2            brier     0.065358
# 3         loss_bce     0.242791
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.293858
# Epoch 4/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.805844
# 1            auprc     0.323603
# 2            brier     0.057974
# 3         loss_bce     0.217396
# 4  specificity_0.5     1.000000
# 5    precision_0.5     1.000000
# 6       recall_0.5     0.002820
# 0             loss     0.234691
# Phase: val:
#             metric  performance
# 0              auc     0.758339
# 1            auprc     0.163147
# 2            brier     0.065169
# 3         loss_bce     0.240218
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.299540
# Epoch 5/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.814081
# 1            auprc     0.345329
# 2            brier     0.059154
# 3         loss_bce     0.219460
# 4  specificity_0.5     1.000000
# 5    precision_0.5     1.000000
# 6       recall_0.5     0.019313
# 0             loss     0.235241
# Phase: val:
#             metric  performance
# 0              auc     0.766187
# 1            auprc     0.168592
# 2            brier     0.065255
# 3         loss_bce     0.238864
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.302526
# Epoch 6/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.823467
# 1            auprc     0.383142
# 2            brier     0.055858
# 3         loss_bce     0.208569
# 4  specificity_0.5     1.000000
# 5    precision_0.5     1.000000
# 6       recall_0.5     0.043454
# 0             loss     0.221041
# Phase: val:
#             metric  performance
# 0              auc     0.774853
# 1            auprc     0.172461
# 2            brier     0.065453
# 3         loss_bce     0.237255
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.302049
# Epoch 7/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.828584
# 1            auprc     0.397782
# 2            brier     0.056978
# 3         loss_bce     0.211332
# 4  specificity_0.5     0.998734
# 5    precision_0.5     0.839572
# 6       recall_0.5     0.082458
# 0             loss     0.221382
# Phase: val:
#             metric  performance
# 0              auc     0.775343
# 1            auprc     0.172024
# 2            brier     0.065816
# 3         loss_bce     0.236634
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.306198
# Epoch 8/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.838110
# 1            auprc     0.401231
# 2            brier     0.054883
# 3         loss_bce     0.203034
# 4  specificity_0.5     0.997220
# 5    precision_0.5     0.782895
# 6       recall_0.5     0.128302
# 0             loss     0.209120
# Phase: val:
#             metric  performance
# 0              auc     0.778613
# 1            auprc     0.173140
# 2            brier     0.066139
# 3         loss_bce     0.236310
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.308709
# Epoch 9/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.836098
# 1            auprc     0.400630
# 2            brier     0.054631
# 3         loss_bce     0.202264
# 4  specificity_0.5     0.996168
# 5    precision_0.5     0.754717
# 6       recall_0.5     0.151106
# 0             loss     0.210433
# Phase: val:
#             metric  performance
# 0              auc     0.779267
# 1            auprc     0.169825
# 2            brier     0.066523
# 3         loss_bce     0.236448
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.310260
# Best performance: 0.280926
# {'performance':      phase  epoch           metric  performance
#  0    train      0              auc     0.518929
#  1    train      0            auprc     0.070546
#  2    train      0            brier     0.156061
#  3    train      0         loss_bce     0.483661
#  4    train      0  specificity_0.5     0.817290
#  ..     ...    ...              ...          ...
#  155    val      9         loss_bce     0.236448
#  156    val      9  specificity_0.5     1.000000
#  157    val      9    precision_0.5     0.000000
#  158    val      9       recall_0.5     0.000000
#  159    val      9             loss     0.310260
#
#  [160 rows x 4 columns]}

# %% [markdown]
# #### Group DRO with IRM Penalty

# %%
model_class = group_robust_model(model_type="IRM_penalty_proxy")
m = model_class(**{
        "num_epochs":10,
        "input_dim":next(iter(loaders['train']))['features'].shape[1],
        "num_groups":4,
        "lr_lambda":1e-1
    }
)
# Out:
# cpu

# %%
m.train(loaders)
# Out:
# Epoch 0/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.516736
# 1            auprc     0.075077
# 2            brier     0.106699
# 3         loss_bce     0.373032
# 4  specificity_0.5     0.975811
# 5    precision_0.5     0.084395
# 6       recall_0.5     0.028978
# 0             loss     0.371462
# Phase: val:
#             metric  performance
# 0              auc     0.538914
# 1            auprc     0.096358
# 2            brier     0.069749
# 3         loss_bce     0.271227
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.269769
# Best model updated
# Epoch 1/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.636562
# 1            auprc     0.129468
# 2            brier     0.065598
# 3         loss_bce     0.252060
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.249095
# Phase: val:
#             metric  performance
# 0              auc     0.639470
# 1            auprc     0.123488
# 2            brier     0.067374
# 3         loss_bce     0.257527
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.254353
# Best model updated
# Epoch 2/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.763679
# 1            auprc     0.255064
# 2            brier     0.062560
# 3         loss_bce     0.235863
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.230383
# Phase: val:
#             metric  performance
# 0              auc     0.676422
# 1            auprc     0.132237
# 2            brier     0.066918
# 3         loss_bce     0.253313
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.250700
# Best model updated
# Epoch 3/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.791523
# 1            auprc     0.328765
# 2            brier     0.061772
# 3         loss_bce     0.229660
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.225983
# Phase: val:
#             metric  performance
# 0              auc     0.707816
# 1            auprc     0.144215
# 2            brier     0.066371
# 3         loss_bce     0.248963
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.246613
# Best model updated
# Epoch 4/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.819074
# 1            auprc     0.381237
# 2            brier     0.061017
# 3         loss_bce     0.223821
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.218991
# Phase: val:
#             metric  performance
# 0              auc     0.722695
# 1            auprc     0.145628
# 2            brier     0.066033
# 3         loss_bce     0.245507
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.243161
# Best model updated
# Epoch 5/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.837247
# 1            auprc     0.422632
# 2            brier     0.058433
# 3         loss_bce     0.213127
# 4  specificity_0.5     1.000000
# 5    precision_0.5     1.000000
# 6       recall_0.5     0.000533
# 0             loss     0.206982
# Phase: val:
#             metric  performance
# 0              auc     0.733649
# 1            auprc     0.150908
# 2            brier     0.065786
# 3         loss_bce     0.242764
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.239911
# Best model updated
# Epoch 6/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.843628
# 1            auprc     0.439147
# 2            brier     0.056640
# 3         loss_bce     0.206780
# 4  specificity_0.5     1.000000
# 5    precision_0.5     1.000000
# 6       recall_0.5     0.040512
# 0             loss     0.203007
# Phase: val:
#             metric  performance
# 0              auc     0.741171
# 1            auprc     0.156221
# 2            brier     0.065564
# 3         loss_bce     0.240792
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.237186
# Best model updated
# Epoch 7/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.851735
# 1            auprc     0.450338
# 2            brier     0.053325
# 3         loss_bce     0.195531
# 4  specificity_0.5     1.000000
# 5    precision_0.5     1.000000
# 6       recall_0.5     0.054009
# 0             loss     0.190495
# Phase: val:
#             metric  performance
# 0              auc     0.748692
# 1            auprc     0.161203
# 2            brier     0.065508
# 3         loss_bce     0.239914
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.235302
# Best model updated
# Epoch 8/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.857582
# 1            auprc     0.469990
# 2            brier     0.054561
# 3         loss_bce     0.198181
# 4  specificity_0.5     1.000000
# 5    precision_0.5     1.000000
# 6       recall_0.5     0.077086
# 0             loss     0.192545
# Phase: val:
#             metric  performance
# 0              auc     0.754251
# 1            auprc     0.169810
# 2            brier     0.065330
# 3         loss_bce     0.238373
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.233827
# Best model updated
# Epoch 9/9
# ----------
# Phase: train:
#             metric  performance
# 0              auc     0.870956
# 1            auprc     0.483711
# 2            brier     0.051765
# 3         loss_bce     0.187873
# 4  specificity_0.5     1.000000
# 5    precision_0.5     1.000000
# 6       recall_0.5     0.089520
# 0             loss     0.180736
# Phase: val:
#             metric  performance
# 0              auc     0.759483
# 1            auprc     0.176656
# 2            brier     0.065180
# 3         loss_bce     0.237197
# 4  specificity_0.5     1.000000
# 5    precision_0.5     0.000000
# 6       recall_0.5     0.000000
# 0             loss     0.231907
# Best model updated
# Best performance: 0.231907
# {'performance':      phase  epoch           metric  performance
#  0    train      0              auc     0.516736
#  1    train      0            auprc     0.075077
#  2    train      0            brier     0.106699
#  3    train      0         loss_bce     0.373032
#  4    train      0  specificity_0.5     0.975811
#  ..     ...    ...              ...          ...
#  155    val      9         loss_bce     0.237197
#  156    val      9  specificity_0.5     1.000000
#  157    val      9    precision_0.5     0.000000
#  158    val      9       recall_0.5     0.000000
#  159    val      9             loss     0.231907
#
#  [160 rows x 4 columns]}
